# %%
import pandas as pd
import math
import numpy as np

# %%
df = pd.read_csv('./Ready2CMI.csv')

# %%
df['edition'] = 'Die Korrespondenz der Constance de Salm (1767-1845). Inventar des Fonds Salm der Société des Amis du Vieux Toulon et de sa Région und des Bestands Constance de Salm im Archiv Schloss Dyck (Mitgliedsarchiv der Vereinigten Adelsarchiv im Rheinland e.V.). Elektronische Edition, DHI PAris 2020.'

# %%
df2 = df[pd.notnull(df['addressee'])]
df2 = df2[pd.notnull(df['sender'])]

# %%
df2
# Out:
#                                                   sender  \
# 30     Jovin-Deshayes, Monsieur (Bürgermeister von Sa...
# 31                                 Dolomieu, marquise de
# 240                                Raboteau, Pierre Paul
# 241    Duval, Amaury, eigentl. Charles-Alexandre-Amau...
# 242                               Langlès, Louis-Mathieu
# ...                                                  ...
# 10958                           Salm, Constance de (CdS)
# 10959                           Salm, Constance de (CdS)
# 10960                           Salm, Constance de (CdS)
# 10961                         Alibert, Jean-Louis, baron
# 10962                         Alibert, Jean-Louis, baron
#
#                               senderID  \
# 30                                 NaN
# 31                                 NaN
# 240    http://d-nb.info/gnd/1067648739
# 241     http://d-nb.info/gnd/116258659
# 242     http://d-nb.info/gnd/116725087
# ...

# %%
df2.to_csv('./Ready2CMIF.csv', index=False)
